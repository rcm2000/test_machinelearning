# %%
import sklearn

# %%
import pandas as pd

# %%
import numpy as np

# %%
nyctaxi = pd.read_csv('./files/nyc-taxi-trip-duration_train.csv')

# %%
nyctaxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458644 entries, 0 to 1458643
# Data columns (total 11 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   id                  1458644 non-null  object
#  1   vendor_id           1458644 non-null  int64
#  2   pickup_datetime     1458644 non-null  object
#  3   dropoff_datetime    1458644 non-null  object
#  4   passenger_count     1458644 non-null  int64
#  5   pickup_longitude    1458644 non-null  float64
#  6   pickup_latitude     1458644 non-null  float64
#  7   dropoff_longitude   1458644 non-null  float64
#  8   dropoff_latitude    1458644 non-null  float64
#  9   store_and_fwd_flag  1458644 non-null  object
#  10  trip_duration       1458644 non-null  int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 122.4+ MB

# %%
nyctaxi
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0        id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1        id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2        id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3        id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4        id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# ...            ...        ...                  ...                  ...
# 1458639  id2376096          2  2016-04-08 13:31:04  2016-04-08 13:44:02
# 1458640  id1049543          1  2016-01-10 07:35:15  2016-01-10 07:46:10
# 1458641  id2304944          2  2016-04-22 06:57:41  2016-04-22 07:10:25
# 1458642  id2714485          1  2016-01-05 15:56:26  2016-01-05 16:02:39
# 1458643  id1209952          1  2016-04-05 14:44:25  2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# ...

# %%
nyctaxi['x'] = (nyctaxi.pickup_longitude - nyctaxi.dropoff_longitude)**2
nyctaxi['y'] = (nyctaxi.pickup_latitude - nyctaxi.dropoff_latitude)**2
nyctaxi['distance_sqrt'] = nyctaxi.x + nyctaxi.y
nyctaxi['distance'] = np.sqrt(nyctaxi.distance_sqrt) * 1000
nyctaxi['speed'] = nyctaxi.distance / nyctaxi.trip_duration * 1000

# %%
nyctaxi
# Out:
#                 id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0        id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1        id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2        id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3        id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4        id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
# ...            ...        ...                  ...                  ...
# 1458639  id2376096          2  2016-04-08 13:31:04  2016-04-08 13:44:02
# 1458640  id1049543          1  2016-01-10 07:35:15  2016-01-10 07:46:10
# 1458641  id2304944          2  2016-04-22 06:57:41  2016-04-22 07:10:25
# 1458642  id2714485          1  2016-01-05 15:56:26  2016-01-05 16:02:39
# 1458643  id1209952          1  2016-04-05 14:44:25  2016-04-05 14:47:43
#
#          passenger_count  pickup_longitude  pickup_latitude  \
# ...

# %%
x = nyctaxi[['distance']]
y = nyctaxi[['trip_duration']]

# %%
x.shape , y.shape
# Out:
# ((1458644, 1), (1458644, 1))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x,y)
X_train.shape ,X_test.shape ,Y_train.shape ,Y_test.shape
# Out:
# ((1093983, 1), (364661, 1), (1093983, 1), (364661, 1))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
lr.coef_,lr.intercept_
# Out:
# (array([[10.86582875]]), array([573.94743063]))

# %%
lr.score(x,y)
# Out:
# 0.009094975391846782

# %%
lr.score(X_train,Y_train)
# Out:
# 0.008307644411527648

# %%
lr.predict([[]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-f124472323f8> in <module>
# ----> 1 lr.predict([[455,38.856131]])
#
# c:\python\python36\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# c:\python\python36\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     220         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     221         return safe_sparse_dot(X, self.coef_.T,
# --> 222                                dense_output=True) + self.intercept_
#     223
#     224     def predict(self, X):
#
# c:\python\python36\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
# ...

# %%
y
# Out:
#          trip_duration
# 0                  455
# 1                  663
# 2                 2124
# 3                  429
# 4                  435
# ...                ...
# 1458639            778
# 1458640            655
# 1458641            764
# 1458642            373
# 1458643            198
#
# [1458644 rows x 1 columns]

# %%
x
# Out:
#           distance
# 0        17.679539
# 1        20.455904
# 2        59.933799
# 3        13.438206
# 4        10.689569
# ...            ...
# 1458639  13.791401
# 1458640  57.997754
# 1458641  76.326934
# 1458642  10.962318
# 1458643  11.105652
#
# [1458644 rows x 1 columns]
